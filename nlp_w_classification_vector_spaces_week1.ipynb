# %%
import pandas as pd
import re
import collections
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv('data/twitter_sentiment_analysis_data_raw.csv', encoding='latin-1', names=['label', 'id', 'data', 'query', 'author', 'tweet'])

# %%
data.head()
# Out:
#    label          id                          data     query           author  \
# 0      0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                tweet
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
data.loc[data['label']==4, 'label'] = 1
data.label.value_counts()
# Out:
# 0    800000
# 1    800000
# Name: label, dtype: int64

# %%
data.head()
# Out:
#    label          id                          data     query           author  \
# 0      0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                tweet
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
df = data.groupby('label').head(1250).reset_index(drop=True)
df['bias'] = 1

# %%
df.label.value_counts()
# Out:
# 0    1250
# 1    1250
# Name: label, dtype: int64

# %%
df.head()
# Out:
#    label          id                          data     query           author  \
# 0      0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                tweet  bias
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...     1
# 1  is upset that he can't update his Facebook by ...     1
# 2  @Kenichan I dived many times for the ball. Man...     1
# 3    my whole body feels itchy and like its on fire      1
# 4  @nationwideclass no, it's not behaving at all....     1

# %%
train, val_test = train_test_split(df, test_size=0.4, random_state=42)

# %%
def build_vocabularies(data, label_col, sentence_col):

    stop_words = ["0s","3a","3b","3d","6b","6o","a","a1","a2","a3","a4","ab","able","about","above","abst","ac","accordance","according","accordingly","across","act","actually","ad","added","adj","ae","af","affected","affecting","affects","after","afterwards","ag","again","against","ah","ain","ain't","aj","al","all","allow","allows","almost","alone","along","already","also","although","always","am","among","amongst","amoungst","amount","an","and","announce","another","any","anybody","anyhow","anymore","anyone","anything","anyway","anyways","anywhere","ao","ap","apart","apparently","appear","appreciate","appropriate","approximately","ar","are","aren","arent","aren't","arise","around","as","a's","aside","ask","asking","associated","at","au","auth","av","available","aw","away","awfully","ax","ay","az","b","b1","b2","b3","ba","back","bc","bd","be","became","because","become","becomes","becoming","been","before","beforehand","begin","beginning","beginnings","begins","behind","being","believe","below","beside","besides","best","better","between","beyond","bi","bill","biol","bj","bk","bl","bn","both","bottom","bp","br","brief","briefly","bs","bt","bu","but","bx","by","c","c1","c2","c3","ca","call","came","can","cannot","cant","can't","cause","causes","cc","cd","ce","certain","certainly","cf","cg","ch","changes","ci","cit","cj","cl","clearly","cm","c'mon","cn","co","com","come","comes","con","concerning","consequently","consider","considering","contain","containing","contains","corresponding","could","couldn","couldnt","couldn't","course","cp","cq","cr","cry","cs","c's","ct","cu","currently","cv","cx","cy","cz","d","d2","da","date","dc","dd","de","definitely","describe","described","despite","detail","df","di","did","didn","didn't","different","dj","dk","dl","do","does","doesn","doesn't","doing","don","done","don't","down","downwards","dp","dr","ds","dt","du","due","during","dx","dy","e","e2","e3","ea","each","ec","ed","edu","ee","ef","effect","eg","ei","eight","eighty","either","ej","el","eleven","else","elsewhere","em","empty","en","end","ending","enough","entirely","eo","ep","eq","er","es","especially","est","et","et-al","etc","eu","ev","even","ever","every","everybody","everyone","everything","everywhere","ex","exactly","example","except","ey","f","f2","fa","far","fc","few","ff","fi","fifteen","fifth","fify","fill","find","fire","first","five","fix","fj","fl","fn","fo","followed","following","follows","for","former","formerly","forth","forty","found","four","fr","from","front","fs","ft","fu","full","further","furthermore","fy","g","ga","gave","ge","get","gets","getting","gi","give","given","gives","giving","gj","gl","go","goes","going","gone","got","gotten","gr","greetings","gs","gy","h","h2","h3","had","hadn","hadn't","happens","hardly","has","hasn","hasnt","hasn't","have","haven","haven't","having","he","hed","he'd","he'll","hello","help","hence","her","here","hereafter","hereby","herein","heres","here's","hereupon","hers","herself","hes","he's","hh","hi","hid","him","himself","his","hither","hj","ho","home","hopefully","how","howbeit","however","how's","hr","hs","http","hu","hundred","hy","i","i2","i3","i4","i6","i7","i8","ia","ib","ibid","ic","id","i'd","ie","if","ig","ignored","ih","ii","ij","il","i'll","im","i'm","immediate","immediately","importance","important","in","inasmuch","inc","indeed","index","indicate","indicated","indicates","information","inner","insofar","instead","interest","into","invention","inward","io","ip","iq","ir","is","isn","isn't","it","itd","it'd","it'll","its","it's","itself","iv","i've","ix","iy","iz","j","jj","jr","js","jt","ju","just","k","ke","keep","keeps","kept","kg","kj","km","know","known","knows","ko","l","l2","la","largely","last","lately","later","latter","latterly","lb","lc","le","least","les","less","lest","let","lets","let's","lf","like","liked","likely","line","little","lj","ll","ll","ln","lo","look","looking","looks","los","lr","ls","lt","ltd","m","m2","ma","made","mainly","make","makes","many","may","maybe","me","mean","means","meantime","meanwhile","merely","mg","might","mightn","mightn't","mill","million","mine","miss","ml","mn","mo","more","moreover","most","mostly","move","mr","mrs","ms","mt","mu","much","mug","must","mustn","mustn't","my","myself","n","n2","na","name","namely","nay","nc","nd","ne","near","nearly","necessarily","necessary","need","needn","needn't","needs","neither","never","nevertheless","new","next","ng","ni","nine","ninety","nj","nl","nn","no","nobody","non","none","nonetheless","noone","nor","normally","nos","not","noted","nothing","novel","now","nowhere","nr","ns","nt","ny","o","oa","ob","obtain","obtained","obviously","oc","od","of","off","often","og","oh","oi","oj","ok","okay","ol","old","om","omitted","on","once","one","ones","only","onto","oo","op","oq","or","ord","os","ot","other","others","otherwise","ou","ought","our","ours","ourselves","out","outside","over","overall","ow","owing","own","ox","oz","p","p1","p2","p3","page","pagecount","pages","par","part","particular","particularly","pas","past","pc","pd","pe","per","perhaps","pf","ph","pi","pj","pk","pl","placed","please","plus","pm","pn","po","poorly","possible","possibly","potentially","pp","pq","pr","predominantly","present","presumably","previously","primarily","probably","promptly","proud","provides","ps","pt","pu","put","py","q","qj","qu","que","quickly","quite","qv","r","r2","ra","ran","rather","rc","rd","re","readily","really","reasonably","recent","recently","ref","refs","regarding","regardless","regards","related","relatively","research","research-articl","respectively","resulted","resulting","results","rf","rh","ri","right","rj","rl","rm","rn","ro","rq","rr","rs","rt","ru","run","rv","ry","s","s2","sa","said","same","saw","say","saying","says","sc","sd","se","sec","second","secondly","section","see","seeing","seem","seemed","seeming","seems","seen","self","selves","sensible","sent","serious","seriously","seven","several","sf","shall","shan","shan't","she","shed","she'd","she'll","shes","she's","should","shouldn","shouldn't","should've","show","showed","shown","showns","shows","si","side","significant","significantly","similar","similarly","since","sincere","six","sixty","sj","sl","slightly","sm","sn","so","some","somebody","somehow","someone","somethan","something","sometime","sometimes","somewhat","somewhere","soon","sorry","sp","specifically","specified","specify","specifying","sq","sr","ss","st","still","stop","strongly","sub","substantially","successfully","such","sufficiently","suggest","sup","sure","sy","system","sz","t","t1","t2","t3","take","taken","taking","tb","tc","td","te","tell","ten","tends","tf","th","than","thank","thanks","thanx","that","that'll","thats","that's","that've","the","their","theirs","them","themselves","then","thence","there","thereafter","thereby","thered","therefore","therein","there'll","thereof","therere","theres","there's","thereto","thereupon","there've","these","they","theyd","they'd","they'll","theyre","they're","they've","thickv","thin","think","third","this","thorough","thoroughly","those","thou","though","thoughh","thousand","three","throug","through","throughout","thru","thus","ti","til","tip","tj","tl","tm","tn","to","together","too","took","top","toward","towards","tp","tq","tr","tried","tries","truly","try","trying","ts","t's","tt","tv","twelve","twenty","twice","two","tx","u","u201d","ue","ui","uj","uk","um","un","under","unfortunately","unless","unlike","unlikely","until","unto","uo","up","upon","ups","ur","us","use","used","useful","usefully","usefulness","uses","using","usually","ut","v","va","value","various","vd","ve","ve","very","via","viz","vj","vo","vol","vols","volumtype","vq","vs","vt","vu","w","wa","want","wants","was","wasn","wasnt","wasn't","way","we","wed","we'd","welcome","well","we'll","well-b","went","were","we're","weren","werent","weren't","we've","what","whatever","what'll","whats","what's","when","whence","whenever","when's","where","whereafter","whereas","whereby","wherein","wheres","where's","whereupon","wherever","whether","which","while","whim","whither","who","whod","whoever","whole","who'll","whom","whomever","whos","who's","whose","why","why's","wi","widely","will","willing","wish","with","within","without","wo","won","wonder","wont","won't","words","world","would","wouldn","wouldnt","wouldn't","www","x","x1","x2","x3","xf","xi","xj","xk","xl","xn","xo","xs","xt","xv","xx","y","y2","yes","yet","yj","yl","you","youd","you'd","you'll","your","youre","you're","yours","yourself","yourselves","you've","yr","ys","yt","z","zero","zi","zz"]
    re_punctuations = """,|'|\.|!|\?|&|"|:|[|]|;|quot|\\/|ing|\\(|\\)"""
    
    pos_vocabulary = [
        re.sub(re_punctuations,'', word.lower())
        for tweet in df.loc[df[label_col]==1, sentence_col].values.tolist() 
        for word in tweet.split(' ') 
        if len(word) > 1 
        and '@' not in word 
        and re.sub(re_punctuations,'', word.lower()) not in stop_words 
        and 'www' not in word
        and 'http' not in word
        and '.com' not in word
    ]
    
    neg_vocabulary = [
        re.sub(re_punctuations,'', word.lower())
        for tweet in data.loc[df[label_col]==0, sentence_col].values.tolist() 
        for word in tweet.split(' ') 
        if len(word) > 1 
        and '@' not in word 
        and re.sub(re_punctuations,'', word.lower()) not in stop_words 
        and 'www' not in word
        and 'http' not in word
        and '.com' not in word
    ]

    
    return pos_vocabulary, neg_vocabulary
    
pos_vocabulary, neg_vocabulary = build_vocabularies(train, 'label', 'tweet')

# %%
neg_freq = collections.Counter(x for x in neg_vocabulary)
pos_freq = collections.Counter(x for x in pos_vocabulary)

# %%
neg_freq
# Out:
# Counter({'sick': 17,
#          'feel': 37,
#          'bit': 5,
#          'medicine': 1,
#          'hope': 11,
#          'good': 28,
#          'night': 17,
#          'sleep': 33,
#          'ohh': 2,
#          'suppose': 1,
#          'snow': 4,
#          'wtf': 1,
#          '_secretgarden_': 1,
#          'havent': 7,
#          'porn': 1,
#          'spammers': 1,
#          'dont': 39,
#          'check': 5,
#          'followers': 2,
#          'tweets': 4,
#          'stillllll': 1,
#          'arrived': 1,
#          'ordered': 2,
#          'maternity': 1,
#          'clothes': 2,
#          'online': 3,
#          'today': 27,
#          'someth': 4,
#          'strange': 1,
#          'didnt': 14,
#          'order': 3,
#          'size': 1,
#          'stuff': 8,
#          'boredd': 2,
#          'gah': 2,
#          'ive': 17,
#          'toooo': 1,
#          'muchh': 1,
#          'cooooffffeeeeeeeee': 1,
#          'bahaha': 1,
#          'art': 3,
#          'tomorrow': 26,
#          'nice': 5,
#          'youve': 2,
#          'joined': 1,
#          'twitter': 13,
#          'wanted': 3,
#          'happen': 3,
#          'persons': 1,
#          'mind': 3,
#          'ish': 1,
#          'prayers': 3,
#          'fam': 3,
#          'real': 1,
#          'completely': 1,
#          'wiped': 1,
#          'reloaded': 1,
#          '8900': 1,
#          'lost': 14,
#          'bbm': 1,
#          'contacts': 2,
#          'bed': 15,
#          'sad': 35,
#          'yeah': 5,
#          'depress': 2,
#          'hav': 6,
#          '#therapyfail': 1,
#          '311': 1,
#          'veiws': 1,
#          'sites': 1,
#          'updates': 5,
#          'time': 25,
#          'gmt+1': 1,
#          'grr': 1,
#          'school': 14,
#          'pain': 6,
#          'sides': 1,
#          'hurt': 3,
#          'mention': 2,
#          'fail': 2,
#          'class': 6,
#          '8-12': 1,
#          'work': 46,
#          '12-3': 1,
#          'gym': 1,
#          '3-5': 1,
#          '6': 1,
#          '6-10': 1,
#          'day': 35,
#          'gonna': 11,
#          'fly': 3,
#          'girlfriend': 2,
#          'shit': 3,
#          'sadly': 4,
#          'works': 2,
#          'amp': 7,
#          'moment': 2,
#          'internet': 6,
#          'plagues': 1,
#          'productive': 2,
#          'days': 8,
#          'angels': 1,
#          'macheist': 1,
#          '30': 2,
#          'apps': 2,
#          'sweet': 2,
#          'espresso': 1,
#          'serial': 1,
#          'derrick': 1,
#          'leav': 4,
#          'park': 2,
#          'lot': 3,
#          'place': 3,
#          'daysany': 1,
#          'packpaintclean': 1,
#          'appreciated': 1,
#          'rip': 3,
#          'wall': 2,
#          'hate': 17,
#          'tuesdays': 1,
#          'vacation': 2,
#          'photos': 2,
#          'yrs': 1,
#          'ago': 6,
#          'crashed': 1,
#          'forget': 2,
#          'site': 3,
#          'presentation': 1,
#          '23': 1,
#          'slides': 1,
#          'week': 10,
#          'hardest': 2,
#          'weeks': 5,
#          'procrastinat': 2,
#          'organiz': 1,
#          'hahaha': 3,
#          'suriously': 1,
#          'joke': 1,
#          'happy': 5,
#          'afraid': 3,
#          'headache': 3,
#          'effgggg': 1,
#          'ughh': 2,
#          'sized': 1,
#          'lonely': 2,
#          'hubby': 1,
#          'puppy': 4,
#          'kitty': 1,
#          'conference': 1,
#          'lmao': 4,
#          'wait': 20,
#          'season': 8,
#          'summe': 1,
#          'boo': 2,
#          'hot': 5,
#          'dry': 1,
#          'ass': 3,
#          'weather': 3,
#          'goodnights': 1,
#          'option': 1,
#          'video': 5,
#          'games': 3,
#          'everyth': 4,
#          'matter': 2,
#          'yesterdays': 2,
#          'news': 5,
#          'goodniight': 1,
#          'dived': 1,
#          'times': 3,
#          'ball': 1,
#          'managed': 2,
#          'save': 1,
#          '50%': 1,
#          'rest': 2,
#          'bounds': 1,
#          'waitis': 1,
#          'game': 4,
#          'episodes': 1,
#          'confused': 4,
#          'jew-bus': 1,
#          'years': 2,
#          'worth': 1,
#          'classes': 2,
#          'alot': 2,
#          'organize': 1,
#          'gt_lt': 1,
#          'finish': 2,
#          'tonight': 8,
#          'possiblemy': 1,
#          'bones': 1,
#          'ache': 1,
#          'misses': 2,
#          'hug': 4,
#          'read': 6,
#          'posts': 1,
#          'properly': 1,
#          'congrats': 1,
#          'totally': 7,
#          'jealous': 3,
#          'xm': 1,
#          'kinda': 2,
#          'yucky': 3,
#          '5am': 3,
#          'quick': 1,
#          'spent': 3,
#          'hour': 8,
#          'reach': 1,
#          'axis': 1,
#          'bank': 2,
#          'holiday': 2,
#          'mahavir': 1,
#          'jayanti': 1,
#          'contd': 1,
#          'finished': 2,
#          'delicious': 1,
#          'breakfast': 2,
#          'paris': 2,
#          'ill': 12,
#          'milk': 2,
#          'europe': 1,
#          'tastiest': 1,
#          'drink': 2,
#          'aww': 3,
#          'felt': 2,
#          'yesterday': 5,
#          'pity': 1,
#          'youtube': 1,
#          'blocked': 1,
#          'china': 1,
#          'vids': 1,
#          'horrible': 4,
#          'sore': 3,
#          'throat': 5,
#          'hurts': 7,
#          'thought': 5,
#          'f1': 1,
#          'regrett': 1,
#          'decision': 2,
#          'elsess': 1,
#          'stupid': 3,
#          'eat': 6,
#          'fish': 2,
#          'guess': 7,
#          '*sigh*': 3,
#          'card': 1,
#          'doa': 1,
#          'left': 3,
#          'ids': 1,
#          'location': 2,
#          'bars': 1,
#          'fuckkkkkkkkkkkkk': 1,
#          'accord': 1,
#          'bro': 1,
#          'poo': 1,
#          'fight': 1,
#          'covered': 3,
#          'poop': 1,
#          'picture': 2,
#          'stolen': 2,
#          'soo': 2,
#          'watch': 17,
#          'premiere': 1,
#          'gross': 1,
#          'pimple': 1,
#          'seat': 2,
#          'baby': 4,
#          'paperswell': 1,
#          'forc': 1,
#          'sleepy': 2,
#          'reply': 2,
#          'uni': 4,
#          'ages': 1,
#          'borders': 1,
#          'closed': 1,
#          '10': 4,
#          'nw': 1,
#          'buddy': 2,
#          '25th': 1,
#          'gotta': 6,
#          'repeat': 2,
#          'folio': 1,
#          'cuz': 1,
#          'terms': 2,
#          'wet': 1,
#          'camper': 1,
#          'chance': 4,
#          'softbelly': 1,
#          'isnt': 7,
#          'loud': 2,
#          'karate': 1,
#          'tournament': 1,
#          'movie': 2,
#          'cillian': 1,
#          'murphy': 1,
#          'kenny': 1,
#          'powers': 1,
#          'earthquake': 1,
#          'italy': 1,
#          'sadden': 1,
#          'hours': 12,
#          'naples': 1,
#          'family': 5,
#          'omg': 7,
#          'mouth': 2,
#          'wanna': 9,
#          'untill': 1,
#          'braces': 1,
#          'shower': 4,
#          'wake': 5,
#          'synth': 1,
#          'experiments': 1,
#          'yielded': 1,
#          'noth': 4,
#          'donnies': 1,
#          'tweet': 3,
#          'stats': 1,
#          '700': 2,
#          'repliesand': 1,
#          'jrk': 1,
#          'shouldnt': 1,
#          'stomach': 1,
#          'flip': 1,
#          'finally': 3,
#          'malaysian': 1,
#          'restaurant': 2,
#          'nasi': 1,
#          'lemak': 1,
#          'teh': 1,
#          'tarik': 1,
#          'mereka': 1,
#          'tak': 4,
#          'faham': 1,
#          'bm': 1,
#          'stuck': 5,
#          'some1': 1,
#          'inform': 1,
#          'wow': 1,
#          'shout': 3,
#          'box': 1,
#          'kicked': 2,
#          'fanclub': 1,
#          'chat': 5,
#          'tough': 1,
#          'favorite': 3,
#          'rachel': 1,
#          'jessy': 1,
#          'mak': 4,
#          'guy': 1,
#          'oooooooo': 1,
#          'study': 5,
#          'killed': 3,
#          'character': 1,
#          'upset': 5,
#          'increase': 1,
#          'capacity': 1,
#          'fast': 1,
#          'whale': 1,
#          '+15': 1,
#          'party': 4,
#          'send': 4,
#          'bad': 12,
#          'messages': 1,
#          '3rd': 1,
#          'mixed': 1,
#          'sophmore': 1,
#          'year': 9,
#          'sigh': 3,
#          'midd': 1,
#          'hsng': 2,
#          'friends': 4,
#          'damn': 4,
#          'grow': 2,
#          'plz': 1,
#          'write': 6,
#          'bak': 2,
#          'havnt': 1,
#          'people': 8,
#          'diss': 1,
#          'bands': 1,
#          'trace': 1,
#          'ugly': 3,
#          'love': 10,
#          'atekinzz': 2,
#          'ampamp': 1,
#          'slideshares': 1,
#          'embed': 2,
#          'code': 2,
#          'annoy': 2,
#          'tiny': 1,
#          '#fail': 1,
#          'buttload': 2,
#          'homework': 2,
#          'blegghhhh': 1,
#          'vals': 1,
#          'mac': 2,
#          'iitsc': 1,
#          'clubroom': 1,
#          'sweat': 2,
#          'free': 5,
#          'comp': 1,
#          'lol': 11,
#          'hop': 2,
#          'fall': 3,
#          'modern': 1,
#          'warfare': 1,
#          '2': 2,
#          'halo': 2,
#          'odst': 1,
#          'brutal': 1,
#          'legend': 1,
#          'bioshock': 1,
#          'cash': 2,
#          'hey': 9,
#          'nope': 3,
#          'cuteness': 1,
#          'awhile': 2,
#          're-p': 1,
#          'custom': 1,
#          'icons': 1,
#          '=]': 1,
#          'cool': 6,
#          'edges': 1,
#          'square': 1,
#          'diff': 1,
#          'background': 1,
#          'buy': 3,
#          'macbook': 2,
#          'pro': 1,
#          'inlove': 1,
#          'powerbook': 1,
#          'league': 1,
#          'ownmakes': 1,
#          'mint': 1,
#          'chocolate': 2,
#          'ice': 2,
#          'cream': 1,
#          'cones': 1,
#          'grand': 1,
#          'fuck': 5,
#          'therapist': 1,
#          'clear': 1,
#          'desk': 2,
#          'anyth': 5,
#          'wear': 4,
#          'gosh': 1,
#          'hard': 7,
#          'reaaly': 1,
#          'john': 2,
#          'mayers': 1,
#          'twitters': 2,
#          'rude': 1,
#          'remove': 2,
#          'bitchfucks': 1,
#          'marley': 1,
#          'ohhh': 1,
#          'hang': 1,
#          'gossip': 2,
#          'girl': 7,
#          'addicted': 1,
#          'pleeeease': 1,
#          'reason': 4,
#          'teardrops': 1,
#          'guitar': 1,
#          'break': 5,
#          'heart': 4,
#          'rise': 1,
#          'thesis': 1,
#          'morn': 16,
#          'rainy': 2,
#          'france': 2,
#          'garden': 2,
#          'god': 2,
#          'ruined': 2,
#          'belly': 1,
#          'button': 1,
#          'crap': 3,
#          'dresses': 1,
#          'bathroom': 2,
#          'lakin': 1,
#          'hear': 12,
#          'maggie': 1,
#          'thoughts': 2,
#          'mum': 4,
#          'sisteri': 1,
#          'pack': 3,
#          'overnight': 1,
#          'bag': 1,
#          'hospital': 3,
#          'forgot': 2,
#          'password': 1,
#          'prevent': 1,
#          'tons': 1,
#          'spam': 1,
#          'convert': 1,
#          'movies': 1,
#          'itouch': 1,
#          'ugh92': 1,
#          'degrees': 1,
#          'ankle': 1,
#          'ready': 5,
#          'premier': 2,
#          'realized': 3,
#          'dressed': 1,
#          'broken': 3,
#          'dropp': 1,
#          'foo': 2,
#          'pre': 1,
#          'understand': 1,
#          'moms': 1,
#          'admitted': 1,
#          'fake': 3,
#          'steven': 1,
#          'man': 9,
#          'cmon': 1,
#          'sean': 1,
#          'branch': 1,
#          'midv': 1,
#          'open': 6,
#          'learn': 1,
#          'wwi': 1,
#          'noon': 1,
#          'updatffe': 1,
#          'minutes': 2,
#          'dammit': 2,
#          'furniture': 1,
#          'newsletter': 1,
#          'fares': 1,
#          'unbelievable': 1,
#          'shame': 1,
#          'booked': 1,
#          'paid': 3,
#          'sayyyy': 1,
#          'whaaaa': 1,
#          'invited': 2,
#          'lame': 2,
#          'ha': 1,
#          'suns': 1,
#          'keeeerrrrriiiiii': 1,
#          'post': 2,
#          '224amwonderfullll': 1,
#          'unexpected': 1,
#          'cried': 3,
#          'haha': 10,
#          'listen': 6,
#          'masters': 1,
#          'list': 2,
#          'includes': 1,
#          'convicts': 1,
#          'sprint': 1,
#          '4g': 1,
#          'baltimore': 1,
#          'chicago': 1,
#          'car': 5,
#          'started': 3,
#          'talk': 5,
#          'ooh': 1,
#          'williams': 1,
#          'sonoma': 1,
#          'access': 2,
#          'mythic': 1,
#          'map': 2,
#          're-download': 1,
#          'legendary': 1,
#          'ugh': 5,
#          '600ms': 1,
#          'framed': 1,
#          'roger': 1,
#          'rabbit': 1,
#          'toon': 1,
#          'town': 1,
#          'aaaaand': 2,
#          'literature': 1,
#          'review': 1,
#          'friendly': 1,
#          'cup': 1,
#          'coffee': 1,
#          'company': 5,
#          'missed': 10,
#          'ya': 4,
#          'meet': 4,
#          'mama': 1,
#          'loss': 4,
#          'brother': 3,
#          'dog': 4,
#          'sam': 1,
#          'wcushs': 1,
#          'disease': 1,
#          'goodd': 1,
#          'nightt': 1,
#          'dreams': 2,
#          'everyonee': 1,
#          'jared': 1,
#          'neveerr': 1,
#          'kyte': 1,
#          'sense': 1,
#          'suicide': 1,
#          'refuse': 1,
#          'happened': 3,
#          'buyology': 1,
#          'bedtime': 4,
#          'great': 7,
#          'premise': 1,
#          'turn': 3,
#          'book': 2,
#          'lots': 1,
#          'info': 3,
#          'knew': 2,
#          'sitt': 2,
#          'house': 9,
#          'sooo': 4,
#          'forward': 2,
#          'poor': 8,
#          'mel': 1,
#          'walk': 4,
#          'pick': 2,
#          'icecream': 1,
#          'file': 1,
#          'taxes': 2,
#          'pretty': 5,
#          'coach': 3,
#          'exceptional': 2,
#          'talent': 2,
#          'trounces': 1,
#          'msu': 1,
#          'figure': 2,
#          'pay': 1,
#          'hotel': 3,
#          'pookie': 1,
#          'uti': 1,
#          'nurse': 1,
#          'gabbie': 1,
#          '100%': 2,
#          'sodas': 1,
#          'gamebattles': 1,
#          'promote': 1,
#          'gear': 1,
#          'groove': 1,
#          'unfornately': 2,
#          'ride': 5,
#          'anaheim': 1,
#          'yea': 1,
#          'manaaaaaaaaaaaaaaaaaaaam': 1,
#          'marwan': 1,
#          'accent': 1,
#          'lookin': 1,
#          'all-nighter': 1,
#          'feet': 1,
#          'fell': 2,
#          'bff': 2,
#          'phone': 8,
#          'writ': 1,
#          'long': 7,
#          'paper': 2,
#          'matthew': 1,
#          'died': 3,
#          'sfmta': 1,
#          'budget': 2,
#          'proposal': 2,
#          'april': 3,
#          '200': 1,
#          'city': 3,
#          'hall': 2,
#          'room': 4,
#          '400': 1,
#          'attend': 1,
#          'doesnt': 8,
#          'miserable': 2,
#          'mom': 5,
#          'breast': 1,
#          'cancer': 3,
#          'worried': 3,
#          'revisions': 3,
#          'wasted': 1,
#          'amazly': 1,
#          'beautiful': 1,
#          'pointless': 1,
#          'sucked': 1,
#          'listdid': 1,
#          'offend': 1,
#          'billy': 1,
#          'sleepless': 1,
#          'jeffree': 1,
#          'hair': 1,
#          'color': 1,
#          'permanent': 1,
#          'dye': 1,
#          'fades': 1,
#          'monday': 1,
#          'monkeys': 1,
#          'twin': 1,
#          'heartbroken': 2,
#          '*cry*': 1,
#          'su': 1,
#          'yin': 1,
#          'huen': 1,
#          'tweeted': 1,
#          'unbearable': 1,
#          'guilt': 1,
#          'staff': 1,
#          'liv': 2,
#          'suffered': 1,
#          'fatal': 1,
#          'partion': 1,
#          'itunes': 4,
#          'library': 1,
#          'docs': 1,
#          'pics': 1,
#          'idea': 4,
#          'promo': 1,
#          'codes': 1,
#          'store': 2,
#          'poohpot': 1,
#          'ate': 3,
#          'kant': 1,
#          'cam': 1,
#          'beat': 1,
#          'upp': 1,
#          'embarasssiiiin': 1,
#          'sittin': 1,
#          'wkayla': 1,
#          'reallly': 1,
#          'dis-like': 1,
#          'synch': 1,
#          'mobile': 1,
#          'iphone': 3,
#          'import': 1,
#          '52': 1,
#          'degress': 1,
#          '11pm': 1,
#          'washton': 1,
#          'state': 4,
#          'winter': 1,
#          'spend': 3,
#          'dispatch': 1,
#          'sed': 1,
#          'puerto': 1,
#          'rican': 1,
#          'saturday': 2,
#          'wah': 2,
#          'clip': 1,
#          'el-stupido': 1,
#          'filters': 1,
#          'till': 2,
#          'puter': 1,
#          'blame': 1,
#          '4': 1,
#          'broke': 5,
#          'birthdays': 1,
#          'eve': 2,
#          'wit': 1,
#          'buck': 1,
#          'group': 1,
#          'extraordinare': 1,
#          'leave': 2,
#          'campussome': 1,
#          'torts': 1,
#          'outline': 1,
#          'finished-good': 1,
#          'th-but': 1,
#          '7am': 2,
#          'dtmafiaofficial': 1,
#          'existtheres': 1,
#          'jus': 1,
#          'dtmafia': 1,
#          'dun': 1,
#          'followin': 1,
#          'wht': 1,
#          'laptop': 1,
#          'officially': 2,
#          'dead': 5,
#          '': 11,
#          'enter': 1,
#          'bureaucratic': 1,
#          'nonsense': 1,
#          'march': 1,
#          'waste': 1,
#          'spell': 1,
#          'account': 2,
#          'baked': 1,
#          'cake': 1,
#          'ated': 1,
#          'nah': 1,
#          'received': 1,
#          'stimulus': 1,
#          'twitterholics': 1,
#          'anonymous': 1,
#          'essay': 1,
#          'spr': 2,
#          'plain': 1,
#          'bestie': 2,
#          'ehhh': 1,
#          'weathers': 1,
#          'sleepwide': 1,
#          'awakeand': 1,
#          'boy': 1,
#          'crappy': 1,
#          'drains': 1,
#          'energy': 1,
#          'wouldve': 1,
#          'gun': 1,
#          'zac': 1,
#          'snyders': 1,
#          'doucheclown': 1,
#          'late': 3,
#          '132am': 1,
#          'tipsy': 1,
#          'lonesome': 1,
#          'thatsthats': 1,
#          'schedule': 1,
#          'net': 1,
#          'colddd': 1,
#          'screwed': 2,
#          'bass': 1,
#          'traffic': 2,
#          'journey': 1,
#          'alright': 1,
#          'turtles': 1,
#          'lasts': 1,
#          'longer': 3,
#          'moves': 1,
#          'faster': 2,
#          'gett': 13,
#          'tea': 1,
#          'sleeeep': 1,
#          'jeez': 1,
#          'america': 1,
#          'borez': 1,
#          'msgs': 1,
#          'flash': 1,
#          'hightlight': 1,
#          'life': 10,
#          'yu': 1,
#          'gettin': 1,
#          'wen': 1,
#          'leavin': 2,
#          'kind': 2,
#          'quiet': 2,
#          'skinny': 1,
#          'vegas': 1,
#          'hungry': 2,
#          'statistics': 1,
#          'bunch': 1,
#          'mumbo': 1,
#          'jumbo': 1,
#          'yo': 1,
#          'mommy': 2,
#          'step': 1,
#          'care': 4,
#          'reduce': 1,
#          'number': 1,
#          'cigarettes': 1,
#          'tax': 2,
#          'return': 1,
#          'dream': 1,
#          'pee': 1,
#          'franklin': 1,
#          'street': 1,
#          'jumped': 2,
#          'jenny': 1,
#          'shoe': 1,
#          'fat': 2,
#          'tummy': 1,
#          'rumbles': 1,
#          'brb': 1,
#          'burned': 1,
#          'nausea': 1,
#          'stories': 1,
#          'manually': 1,
#          'twitterfeed': 1,
#          'problem': 3,
#          'weve': 2,
#          'stou': 1,
#          'update': 2,
#          '22552': 1,
#          'exam': 2,
#          'mail': 1,
#          'notices': 1,
#          'doc': 2,
#          'michigan': 2,
#          'hahahahhha': 1,
#          'hows': 2,
#          'food': 2,
#          'poisen': 1,
#          'loads': 1,
#          'calv': 1,
#          'seasonsad': 1,
#          'black': 1,
#          'bottle': 2,
#          'calves': 1,
#          'told': 4,
#          'busy': 1,
#          'latest': 1,
#          'project': 1,
#          'clos': 1,
#          'str': 1,
#          'cheese': 1,
#          'bear': 1,
#          'ua': 1,
#          'embarrass': 1,
#          'log': 1,
#          'netball': 1,
#          'netbal': 1,
#          'abt': 1,
#          'bjorks': 1,
#          'fucked': 1,
#          'struggl': 2,
#          'eam': 1,
#          'law': 1,
#          'india': 1,
#          '100th': 1,
#          'test': 2,
#          'victory': 1,
#          '10th': 1,
#          'consecutive': 1,
#          'win': 3,
#          'gooooood': 1,
#          'moooorniiiiii': 1,
#          'germany': 1,
#          'cageor': 1,
#          'bettermy': 1,
#          'office': 2,
#          'hmmmgreed': 1,
#          'motivates': 1,
#          'individual': 1,
#          'better-not': 1,
#          'takes': 2,
#          'sandra': 3,
#          'cantu': 2,
#          'live': 4,
#          'mea': 1,
#          'culpa': 1,
#          'mines': 1,
#          'fit': 1,
#          'nokia': 2,
#          'ughhh': 1,
#          'advance': 1,
#          'follower': 1,
#          'dang': 4,
#          'earlier': 2,
#          'outs': 1,
#          'planned': 1,
#          'lose': 2,
#          'close': 2,
#          'loved': 2,
#          'bouts': 1,
#          'start': 8,
#          '24': 1,
#          'linny': 1,
#          'eyes': 3,
#          'tired': 10,
#          'reese': 1,
#          '#ttsc': 1,
#          'finale': 1,
#          '#24': 1,
#          'bor': 3,
#          'madame': 1,
#          'president': 1,
#          'crazy': 3,
#          'woman': 1,
#          'exams': 1,
#          'difference': 1,
#          'haif': 1,
#          'circle': 1,
#          'hemisphere': 1,
#          'lt3': 4,
#          'gt': 1,
#          'body': 3,
#          'feels': 4,
#          'itchy': 1,
#          'duckl': 1,
#          'famous': 1,
#          'childrens': 1,
#          'bostons': 1,
#          'public': 1,
#          'boston': 1,
#          'globe': 1,
#          'crew': 1,
#          'contact': 1,
#          '1099': 1,
#          'freelance': 1,
#          '2008': 1,
#          'jesus': 1,
#          'camp': 1,
#          'upload': 2,
#          'correclty': 1,
#          '[': 1,
#          'play': 9,
#          'trumpet': 1,
#          'round': 2,
#          'half': 6,
#          'adopted': 1,
#          'auntie': 2,
#          'tessm64': 1,
#          'awesome': 1,
#          'tania38': 1,
#          'bentley': 1,
#          'manu': 1,
#          'cantus': 1,
#          'difficult': 3,
#          'centre': 1,
#          ...})

# %%
train.head()
# Out:
#       label          id                          data     query  \
# 348       0  1467899025  Mon Apr 06 22:43:06 PDT 2009  NO_QUERY
# 1089      0  1468077685  Mon Apr 06 23:35:28 PDT 2009  NO_QUERY
# 1850      1  1467934783  Mon Apr 06 22:53:09 PDT 2009  NO_QUERY
# 300       0  1467890079  Mon Apr 06 22:40:38 PDT 2009  NO_QUERY
# 1658      1  1467898790  Mon Apr 06 22:43:02 PDT 2009  NO_QUERY
#
#              author                                              tweet  bias
# 348             oup  still sick. feeling a bit better, got some new...     1
# 1089   ann_donnelly  _secretgarden_ I haven't gotten any porn spamm...     1
# 1850  SherylBreuker              @PhoneBoy I can't wait to read that.      1
# 300        BATMANNN             @jokerrrr It stillllll hasn't arrived      1
# 1658    WindyPorter  @JonathanRKnight There is no way on earth that...     1

# %%
re_punctuations = """,|'|\.|!|\?|&|"|:|[|]|;|quot|\\/|ing|\\(|\\)"""
train['adjusted_tweets'] = train.tweet.str.lower().str.replace(re_punctuations, '', regex=True)
val_test['adjusted_tweets'] = val_test.tweet.str.lower().str.replace(re_punctuations, '', regex=True)

# %%
def calculate_scores(sentence, pos_frequency_dict=pos_freq, neg_frequency_dict=neg_freq):
    words_list = sentence.split(' ')
    pos_value = 0
    neg_value = 0
    for word in words_list:
        pos_value += pos_frequency_dict[word]
        neg_value += neg_frequency_dict[word]
    return pos_value, neg_value

# %%
train[["pos_value", "neg_value"]] = train["adjusted_tweets"].map(calculate_scores).tolist()
val_test[["pos_value", "neg_value"]] = val_test["adjusted_tweets"].map(calculate_scores).tolist()

# %%
val_test.head()
# Out:
#       label          id                          data     query  \
# 1447      1  1467861286  Mon Apr 06 22:32:57 PDT 2009  NO_QUERY
# 1114      0  1468083884  Mon Apr 06 23:37:29 PDT 2009  NO_QUERY
# 1064      0  1468072530  Mon Apr 06 23:33:55 PDT 2009  NO_QUERY
# 2287      1  1468007017  Mon Apr 06 23:13:40 PDT 2009  NO_QUERY
# 1537      1  1467864444  Mon Apr 06 22:33:48 PDT 2009  NO_QUERY
#
#              author                                              tweet  bias  \
# 1447  llliizzziiiee  @Westneyrhindxx hello westney  what are you do...     1
# 1114     pstannard1  got woken up this mornng at 7am - damn Lorry ,...     1
# 1064       SarahDeG  Why do I keep looking...I know that what I rea...     1
# 2287   Hetty4Christ  Pray for my friend @growline late work...pray ...     1
# 1537      elysemize  @JonathanRKnight  i do embrace the simple life...     1
#
#                                         adjusted_tweets  pos_value  neg_value
# 1447  @westneyrhindxx hello westney  what are you do  x         87         22
# 1114  got woken up this mornng at 7am - damn lorry  ...        145         50
# 1064  why do i keep looki know that what i read is g...        123         52
# 2287  pray for my friend @growline late workpray it ...        194         48
# 1537  @jonathanrknight  i do embrace the simple life...        211         62

# %%
validation, test = train_test_split(val_test, test_size=0.5, random_state=42)

X_train, y_train = train[['bias', 'pos_value', 'neg_value']].to_numpy(), train['label'].to_numpy()
X_val, y_val = validation[['bias', 'pos_value', 'neg_value']].to_numpy(), validation['label'].to_numpy()
X_test, y_test = test[['bias', 'pos_value', 'neg_value']].to_numpy(), test['label'].to_numpy()
